# %%
import requests
import json
import pandas as pd

# %%
r=requests.get("https://api.nytimes.com/svc/mostpopular/v2/emailed/7.json?api-key=WYWpUaO7ciDq3Ek6uSN5mhluyZtWYRYY")

# %%
data=r.json()["results"]

# %%
df = pd.DataFrame.from_dict(data)

# %%
df
# Out:
#                                                   uri  \
# 0   nyt://article/6fcd3192-a2a6-5f41-90ea-bdfb76f6...
# 1   nyt://article/aded3ea5-492b-5be9-b316-6a898108...
# 2   nyt://article/dc8a71b4-d476-5d7d-a537-62830969...
# 3   nyt://article/8af72b06-257e-5cc7-b136-c9e4ecd0...
# 4   nyt://article/38b77ff8-e80e-5f69-a796-06308279...
# 5   nyt://article/392f3d38-7b8a-5b05-a49c-f7577682...
# 6   nyt://article/51d0a743-8c7c-5dcc-ba74-253c8fb8...
# 7   nyt://article/30a2748d-7667-5600-931f-3bbb1b27...
# 8   nyt://article/bc026af5-e331-566f-aa47-4f9323af...
# 9   nyt://article/aa35eb2c-35be-55c1-b077-d669d55f...
# 10  nyt://article/262f7309-0497-5b72-a1b0-7de5ac30...
# 11  nyt://article/82f586a3-9116-58e6-9d78-fde850e1...
# 12  nyt://article/235e4ad0-107c-5eb8-afa4-585028d8...
# 13  nyt://article/ad10f8a9-2963-5791-8bc8-d2ddaa5f...
# 14  nyt://article/10c897f0-002b-55ac-85ee-fb12aa92...
# 15  nyt://article/4f8affb6-84bf-5c4c-9b99-c1c680cf...
# ...
